# %% [markdown]
# **Image**

# %%
from PIL import Image
image=Image.open('/content/pic2.jpg')

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x450>

# %%
from scipy.ndimage import median_filter
from skimage import io, img_as_ubyte

image=io.imread('/content/pic2.jpg')
denoised_image=median_filter(image,size=3)

# %%
image
# Out:
# array([[[ 96, 160, 222],
#         [ 96, 160, 222],
#         [ 98, 160, 221],
#         ...,
#         [  0, 118, 218],
#         [  0, 118, 218],
#         [  0, 118, 218]],
#
#        [[ 96, 160, 222],
#         [ 96, 160, 222],
#         [ 98, 160, 221],
#         ...,
#         [  0, 118, 218],
#         [  0, 118, 218],
#         [  0, 118, 218]],
#
#        [[ 96, 160, 222],
#         [ 96, 160, 222],
#         [ 98, 160, 221],
#         ...,
#         [  0, 118, 218],
#         [  0, 118, 218],
#         [  0, 118, 218]],
#
#        ...,
#
#        [[ 98,  93,   1],
#         [ 87,  82,   0],
#         [ 67,  67,   0],
#         ...,
#         [ 60, 100,   4],
#         [ 66, 105,  16],
#         [ 86, 124,  37]],
#
#        [[ 74,  80,   8],
#         [ 68,  74,   4],
#         [ 62,  68,   0],
#         ...,
#         [ 71, 111,  14],
#         [ 66, 111,  16],
#         [ 53, 100,   8]],
#
#        [[ 74,  80,   8],
#         [ 68,  74,   4],
#         [ 62,  68,   0],
# ...

# %% [markdown]
# ##2:-Gaussian Filtering

# %%
import cv2
from skimage import io

# %%
image=io.imread('/content/pic2.jpg')
denoised_image=cv2.GaussianBlur(image,(3,3),0)

# %%
#convert the denoised image to uint8 format
denoised_image_uint8=img_as_ubyte(denoised_image)

# %%
#save the image
io.imsave('/content/pic2.jpg',denoised_image_uint8)

# %% [markdown]
# **Denoising Methods**

# %% [markdown]
# **Non-local Means(NLM):**
# Computes the weighted averages of

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import img_as_float
from skimage.restoration import denoise_nl_means
from skimage import data,img_as_float
from skimage.util import random_noise

# %%
#load an ex image with noise
image=data.camera()
image=img_as_float(image)
noisy_image=random_noise(image,var=0.01)

# %%
#Apply Non-Local Means Denoising
denoised_image=denoise_nl_means(noisy_image,h=0.1)

# %%
#display the original
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(image,cmap='gray')
plt.title('Original Image')

plt.subplot(1,2,2)
plt.imshow(denoised_image,cmap='gray')
plt.title('NLM Denoised image')
plt.show()

# %% [markdown]
# ##Linear Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('/content/delivery_time (1).csv')
df
# Out:
#     Delivery Time  Sorting Time
# 0           21.00            10
# 1           13.50             4
# 2           19.75             6
# 3           24.00             9
# 4           29.00            10
# 5           15.35             6
# 6           19.00             7
# 7            9.50             3
# 8           17.90            10
# 9           18.75             9
# 10          19.83             8
# 11          10.75             4
# 12          16.68             7
# 13          11.50             3
# 14          12.03             3
# 15          14.88             4
# 16          13.75             6
# 17          18.11             7
# 18           8.00             2
# 19          17.83             7
# 20          21.50             5

# %%
df.rename(columns = {'Delivery Time':'Delivery_Time','Sorting Time':'Sorting_Time'},inplace=True)

# %% [markdown]
# **Logistic on Climate**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('/content/claimants.csv')

# %%
df
# Out:
#       CASENUM  ATTORNEY  CLMSEX  CLMINSUR  SEATBELT  CLMAGE    LOSS
# 0           5         0     0.0       1.0       0.0    50.0  34.940
# 1           3         1     1.0       0.0       0.0    18.0   0.891
# 2          66         1     0.0       1.0       0.0     5.0   0.330
# 3          70         0     0.0       1.0       1.0    31.0   0.037
# 4          96         1     0.0       1.0       0.0    30.0   0.038
# ...       ...       ...     ...       ...       ...     ...     ...
# 1335    34100         1     0.0       1.0       0.0     NaN   0.576
# 1336    34110         0     1.0       1.0       0.0    46.0   3.705
# 1337    34113         1     1.0       1.0       0.0    39.0   0.099
# 1338    34145         0     1.0       0.0       0.0     8.0   3.177
# 1339    34153         1     1.0       1.0       0.0    30.0   0.688
#
# [1340 rows x 7 columns]

# %%
df.head()
# Out:
#    CASENUM  ATTORNEY  CLMSEX  CLMINSUR  SEATBELT  CLMAGE    LOSS
# 0        5         0     0.0       1.0       0.0    50.0  34.940
# 1        3         1     1.0       0.0       0.0    18.0   0.891
# 2       66         1     0.0       1.0       0.0     5.0   0.330
# 3       70         0     0.0       1.0       1.0    31.0   0.037
# 4       96         1     0.0       1.0       0.0    30.0   0.038

# %%
df.tail()
# Out:
#       CASENUM  ATTORNEY  CLMSEX  CLMINSUR  SEATBELT  CLMAGE   LOSS
# 1335    34100         1     0.0       1.0       0.0     NaN  0.576
# 1336    34110         0     1.0       1.0       0.0    46.0  3.705
# 1337    34113         1     1.0       1.0       0.0    39.0  0.099
# 1338    34145         0     1.0       0.0       0.0     8.0  3.177
# 1339    34153         1     1.0       1.0       0.0    30.0  0.688

# %%
df.mean()
# Out:
# CASENUM     11202.001493
# ATTORNEY        0.488806
# CLMSEX          0.558735
# CLMINSUR        0.907621
# SEATBELT        0.017028
# CLMAGE         28.414422
# LOSS            3.806307
# dtype: float64

# %%
df.median()
# Out:
# CASENUM     8756.5000
# ATTORNEY       0.0000
# CLMSEX         1.0000
# CLMINSUR       1.0000
# SEATBELT       0.0000
# CLMAGE        30.0000
# LOSS           1.0695
# dtype: float64

# %%
df.isnull()
# Out:
#       CASENUM  ATTORNEY  CLMSEX  CLMINSUR  SEATBELT  CLMAGE   LOSS
# 0       False     False   False     False     False   False  False
# 1       False     False   False     False     False   False  False
# 2       False     False   False     False     False   False  False
# 3       False     False   False     False     False   False  False
# 4       False     False   False     False     False   False  False
# ...       ...       ...     ...       ...       ...     ...    ...
# 1335    False     False   False     False     False    True  False
# 1336    False     False   False     False     False   False  False
# 1337    False     False   False     False     False   False  False
# 1338    False     False   False     False     False   False  False
# 1339    False     False   False     False     False   False  False
#
# [1340 rows x 7 columns]

# %%
df.dropna(axis=0,inplace=True)

# %%
df.isnull()
# Out:
#       CASENUM  ATTORNEY  CLMSEX  CLMINSUR  SEATBELT  CLMAGE   LOSS
# 0       False     False   False     False     False   False  False
# 1       False     False   False     False     False   False  False
# 2       False     False   False     False     False   False  False
# 3       False     False   False     False     False   False  False
# 4       False     False   False     False     False   False  False
# ...       ...       ...     ...       ...       ...     ...    ...
# 1334    False     False   False     False     False   False  False
# 1336    False     False   False     False     False   False  False
# 1337    False     False   False     False     False   False  False
# 1338    False     False   False     False     False   False  False
# 1339    False     False   False     False     False   False  False
#
# [1096 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1096 entries, 0 to 1339
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   CASENUM   1096 non-null   int64
#  1   ATTORNEY  1096 non-null   int64
#  2   CLMSEX    1096 non-null   float64
#  3   CLMINSUR  1096 non-null   float64
#  4   SEATBELT  1096 non-null   float64
#  5   CLMAGE    1096 non-null   float64
#  6   LOSS      1096 non-null   float64
# dtypes: float64(5), int64(2)
# memory usage: 68.5 KB

# %%
df.describe()
# Out:
#             CASENUM     ATTORNEY       CLMSEX     CLMINSUR     SEATBELT  \
# count   1096.000000  1096.000000  1096.000000  1096.000000  1096.000000
# mean   11244.278285     0.472628     0.564781     0.904197     0.018248
# std     9425.386224     0.499478     0.496012     0.294455     0.133909
# min        0.000000     0.000000     0.000000     0.000000     0.000000
# 25%     4502.750000     0.000000     0.000000     1.000000     0.000000
# 50%     8730.500000     0.000000     1.000000     1.000000     0.000000
# 75%    16013.000000     1.000000     1.000000     1.000000     0.000000
# max    34153.000000     1.000000     1.000000     1.000000     1.000000
#
#             CLMAGE         LOSS
# count  1096.000000  1096.000000
# mean     28.587591     3.856578
# std      20.392621    10.473239
# min       0.000000     0.000000
# 25%       9.000000     0.440000
# 50%      30.000000     1.311000
# 75%      43.000000     3.910500
# max      95.000000   173.604000

# %%
df.mean()
# Out:
# CASENUM     11244.278285
# ATTORNEY        0.472628
# CLMSEX          0.564781
# CLMINSUR        0.904197
# SEATBELT        0.018248
# CLMAGE         28.587591
# LOSS            3.856578
# dtype: float64

# %%
df.median()
# Out:
# CASENUM     8730.500
# ATTORNEY       0.000
# CLMSEX         1.000
# CLMINSUR       1.000
# SEATBELT       0.000
# CLMAGE        30.000
# LOSS           1.311
# dtype: float64

# %%
df.var()
# Out:
# CASENUM     8.883791e+07
# ATTORNEY    2.494784e-01
# CLMSEX      2.460279e-01
# CLMINSUR    8.670383e-02
# SEATBELT    1.793154e-02
# CLMAGE      4.158590e+02
# LOSS        1.096887e+02
# dtype: float64

# %%
df.std()
# Out:
# CASENUM     9425.386224
# ATTORNEY       0.499478
# CLMSEX         0.496012
# CLMINSUR       0.294455
# SEATBELT       0.133909
# CLMAGE        20.392621
# LOSS          10.473239
# dtype: float64

# %%
df.corr()
# Out:
#            CASENUM  ATTORNEY    CLMSEX  CLMINSUR  SEATBELT    CLMAGE      LOSS
# CASENUM   1.000000  0.017241  0.032632  0.054139 -0.021282 -0.006589 -0.046407
# ATTORNEY  0.017241  1.000000  0.097475  0.084609 -0.060795  0.001132 -0.225769
# CLMSEX    0.032632  0.097475  1.000000  0.058164 -0.017814 -0.017942 -0.029742
# CLMINSUR  0.054139  0.084609  0.058164  1.000000  0.021217  0.048166  0.019502
# SEATBELT -0.021282 -0.060795 -0.017814  0.021217  1.000000 -0.028343  0.131182
# CLMAGE   -0.006589  0.001132 -0.017942  0.048166 -0.028343  1.000000  0.065513
# LOSS     -0.046407 -0.225769 -0.029742  0.019502  0.131182  0.065513  1.000000

# %%
sns.heatmap(df.corr(),annot=True,cmap='coolwarm',fmt='.2f')
# Out:
# <Axes: >

# %%
x=df.iloc[:,1:]
y=df.iloc[:,0]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25)
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test

# %%
x_train
# Out:
#       ATTORNEY  CLMSEX  CLMINSUR  SEATBELT  CLMAGE   LOSS
# 161          1     0.0       1.0       0.0    10.0  0.375
# 752          1     1.0       1.0       0.0    39.0  4.095
# 610          1     0.0       1.0       0.0    33.0  0.596
# 218          1     1.0       1.0       0.0     0.0  0.040
# 1145         1     0.0       1.0       0.0    13.0  0.130
# ...        ...     ...       ...       ...     ...    ...
# 347          1     1.0       1.0       0.0    56.0  3.009
# 1156         0     0.0       1.0       0.0    37.0  1.951
# 462          1     0.0       1.0       0.0    34.0  1.360
# 699          0     1.0       1.0       0.0    43.0  8.490
# 198          0     0.0       1.0       0.0    49.0  0.390
#
# [822 rows x 6 columns]
