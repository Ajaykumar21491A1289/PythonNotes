# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
data=pd.read_csv('/content/Salary Data.csv')

# %%
data.tail()
# Out:
#       Age  Gender Education Level                      Job Title  \
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 370                  8.0   85000.0
# 371                 19.0  170000.0
# 372                  2.0   40000.0
# 373                  7.0   90000.0
# 374                 15.0  150000.0

# %%
data.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
data.isnull().sum()
# Out:
# Age                    2
# Gender                 2
# Education Level        2
# Job Title              2
# Years of Experience    2
# Salary                 2
# dtype: int64

# %%
data.info
# Out:
# <bound method DataFrame.info of       Age  Gender  Education Level  Job Title  Years of Experience    Salary
# 0    32.0       1                0        159                  5.0   90000.0
# 1    28.0       0                1         17                  3.0   65000.0
# 2    45.0       1                2        130                 15.0  150000.0
# 3    36.0       0                0        101                  7.0   60000.0
# 4    52.0       1                1         22                 20.0  200000.0
# ..    ...     ...              ...        ...                  ...       ...
# 370  35.0       0                0        131                  8.0   85000.0
# 371  43.0       1                1         30                 19.0  170000.0
# 372  29.0       0                0         70                  2.0   40000.0
# 373  34.0       1                0        137                  7.0   90000.0
# 374  44.0       0                2        110                 15.0  150000.0
#
# [373 rows x 6 columns]>

# %%
data.dropna(axis=0,inplace=True)

# %%
data.isnull().sum()
# Out:
# Age                    0
# Gender                 0
# Education Level        0
# Job Title              0
# Years of Experience    0
# Salary                 0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
data['Gender']=le.fit_transform(data['Gender'])
data['Education Level']=le.fit_transform(
    data['Education Level'])
data['Job Title']=le.fit_transform(data['Job Title'])

# %%
data.Gender.unique()
# Out:
# array([1, 0])

# %%
data.corr()
# Out:
#                           Age    Gender  Education Level  Job Title  \
# Age                  1.000000 -0.020324         0.562693   0.117629
# Gender              -0.020324  1.000000        -0.044717   0.014307
# Education Level      0.562693 -0.044717         1.000000   0.099934
# Job Title            0.117629  0.014307         0.099934   1.000000
# Years of Experience  0.979128  0.002884         0.590863   0.100162
# Salary               0.922335  0.071106         0.670371   0.136206
#
#                      Years of Experience    Salary
# Age                             0.979128  0.922335
# Gender                          0.002884  0.071106
# Education Level                 0.590863  0.670371
# Job Title                       0.100162  0.136206
# Years of Experience             1.000000  0.930338
# Salary                          0.930338  1.000000

# %%
data.cov()
# Out:
#                                Age       Gender  Education Level  \
# Age                      49.971792    -0.071874         2.878153
# Gender                   -0.071874     0.250267        -0.016187
# Education Level           2.878153    -0.016187         0.523552
# Job Title                38.675639     0.332908         3.363213
# Years of Experience      45.384506     0.009459         2.803317
# Salary               314527.546557  1715.980931     23399.276428
#
#                          Job Title  Years of Experience        Salary
# Age                      38.675639            45.384506  3.145275e+05
# Gender                    0.332908             0.009459  1.715981e+03
# Education Level           3.363213             2.803317  2.339928e+04
# Job Title              2163.312433            30.547108  3.056080e+05
# Years of Experience      30.547108            42.994343  2.942752e+05
# Salary               305607.970106        294275.229900  2.327099e+09

# %%
x=data.drop(['Salary'],axis=1)
y=pd.DataFrame(data['Salary'])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25)

# %%
sns.pairplot(data,hue="Salary")

# %%
from sklearn.linear_model import LinearRegression

# %%
le=LinearRegression()

# %%
le.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=le.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8633340208050673

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 393300387.8802697

# %%
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 19831.80243649754
